# %% [markdown]
# # Webscraping
#
# Output:
#
# ```
# TLD: value
# DOMAIN: value
# HOSTNAME: value
# PATH: /value
# LINKS:
#     Same hostname:
#     Same domain:
#     Different domain:
#
# ```

# %%
import re #regex library
from bs4 import BeautifulSoup # work with html
import requests 
import sys # work with extra cmd argument
from pprint import pprint

# %% [markdown]
# Functions to extract main infomation

# %%
def hostname(url):
    '''
        The function is to find the HOSTNAME
    '''
    
    #pattern of a URL
    if re.search(r"https://", url):
        del_https = url.replace("https://", "")
    if re.search(r"http://", url):
        del_https = url.replace("http://", "")
    
    #extract only Fully Qualified Domain Name 
    fqdn_pattern = r'[^\/]*'
    fqdn = re.match(fqdn_pattern, del_https).group(0) 
    
    return fqdn

# %%
# enrich the domains found
known_domains =  ['.com', '.net', '.org', '.co', '.us']
known_domains = set(known_domains)

def domain(hostname):
    '''
        Find the DOMAIN of a URL
    '''
    
    
    #usually the url has the form: www.abc.domain 
    splits = hostname.split('.', 1) 
    
    #dotted domain: .com
    known_domains.add('.' + splits[-1])

    return splits[-1]

# %%
def main_path(url):
    '''
        Find the PATH of URL
    '''
    hname = hostname(url)
    try:
        pattern = "https://" + hname
        pth = url.replace(pattern, "")
    except:
        pattern = "http://" + hname
        pth = url.replace(pattern, "")
    
    return pth

# %% [markdown]
# Functions to extract and group hidden links

# %%
def sub_links(main_url):
    '''
        Find the hyperlinks from the given URL
    '''
    # open and get all the texts in the website
    page = requests.get(main_url)
    texts = str(BeautifulSoup(page.text, 'html.parser'))

    # general pattern
    pattern1, pattern2 = r'"https://.*?"', r'"http://.*?"'
    
    # find all the links 
    links = re.findall(pattern1, texts) + re.findall(pattern2, texts)
    
    return links

# %%
def grouping(sub_links):
    
    '''
        Group the URL based on DOMAIN, HOSTNAME
    '''
    
    for link in sub_links:
        link = link.replace('"', "") # remove the quote sign 

        # remove the unwanted info in some links separated by whitespace e.g. www.abc.com width=100    
        unrelated_info = re.search(' ', link)
        if unrelated_info:
            link = link[:unrelated_info.start()]
            
        # extract info of the found link
        sub_hname = hostname(link)
        sub_domain = domain(sub_hname)
        
        # compare and append
        if main_hname == sub_hname:
            same_hname.append(link)
        elif main_domain == sub_domain:
            same_domain.append(link)
        elif main_domain != sub_domain:
            diff_domain.append(link)

# %% [markdown]
# This is to display the reulst merely

# %%
def display():
    '''
        Use this to display the results
    '''
    
    print("TLD:", tld)
    print("DOMAIN:", main_domain)
    print("HOSTNAME:", main_hname)
    print("PATH:", path)
    print("LINKS:")
    print("Same hostname:\n")
    pprint(same_hname)
    print("\nSame domain:\n")
    pprint(same_domain)
    print("\nDifferent domain:\n")
    pprint(diff_domain)

# %% [markdown]
# Test with URL = https://edition.cnn.com/

# %%
url = "https://edition.cnn.com/"

same_hname, same_domain, diff_domain = list(), list(), list()

main_hname = hostname(url)
tld = domain(main_hname).split('.', 1)[-1] # domain can be abc.gov.uk
main_domain = domain(main_hname)
path = main_path(url)

hidden_links = sub_links(url)
grouping(hidden_links)

display()
# Out:
# TLD: com
# DOMAIN: cnn.com
# HOSTNAME: edition.cnn.com
# PATH: /
# LINKS:
# Same hostname:
#
# ['https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com/2020/08/17/politics/trump-retweets-known-russian-disinformation-biden-derkach/index.html\\',
#  'https://edition.cnn.com/2020/08/17/opinions/if-trump-loses-and-refuses-to-leave-callan/index.html\\',
#  'https://edition.cnn.com/world/live-news/coronavirus-pandemic-08-18-20-intl/index.html\\',
#  'https://edition.cnn.com/2019/12/27/asia/india-rape-education-intl-hnk/index.html\\',
#  'https://edition.cnn.com/2020/08/14/tech/huawei-kirin-chipsets-hnk-intl/index.html\\',
#  'https://edition.cnn.com/2020/07/06/sport/bryson-dechambeau-rocket-mortgage-classic-pga-tour-golf-spt-intl/index.html\\',
#  'https://edition.cnn.com/sport/golf\\',
#  'https://edition.cnn.com/2013/09/20/world/taliban-fast-facts/index.html\\',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com/business',
#  'https://edition.cnn.com/business']
#
# Same domain:
#
# ['https://www.cnn.com',
#  'https://www.cnn.com',
#  'https://us.cnn.com',
#  'https://www.cnn.com',
#  'https://audience.cnn.com/services/cnn',
#  'https://www.cnn.com/2020/08/17/politics/michelle-obama-speech-transcript/index.html\\',
#  'https://www.cnn.com/election/2020/candidate/trump\\',
#  'https://www.cnn.com/specials/2020-election-video-landing-page\\',
#  'https://www.cnn.com/politics/live-news/dnc-2020-day-1/index.html\\',
#  'https://www.cnn.com/election/2020/candidate/trump\\',
#  'https://www.cnn.com/2020/08/17/politics/democratic-convention-bernie-sanders-michelle-obama/index.html\\',
#  'https://www.cnn.com/2020/07/10/politics/trump-stone-prison-clemency/index.html\\',
#  'https://www.cnn.com/travel/article/death-valley-vandal-confesses-trnd/index.html\\',
#  'https://www.cnn.com/2013/07/10/us/death-valley-heat-anniversary/index.html\\',
#  'https://www.cnn.com/2020/08/05/us/sarmistha-sen-runner-death/index.html\\',
#  'https://www.cnn.com/2019/05/08/health/bubonic-plague-explainer-trnd/index.html\\',
#  'https://www.cnn.com/2020/01/31/entertainment/the-crown-end/index.html\\',
#  'https://www.cnn.com/2020/01/06/health/china-pneumonia-intl-hnk/index.html\\',
#  'https://www.cnn.com/specials/world/coronavirus-outbreak-intl-hnk\\',
#  'https://www.cnn.com/world/live-news/coronavirus-pandemic-08-17-20-intl/index.html\\',
#  'https://www.cnn.com/2019/01/28/us/kamala-harris-fast-facts/index.html\\',
#  'https://www.cnn.com/2018/04/10/football/roma-bareclona-champions-league-intl/index.html\\',
#  'https://www.cnn.com/2019/05/09/sport/ajax-tottenham-champions-league-defeat-reaction-trnd/index.html\\',
#  'https://www.cnn.com/election/2020\\',
#  'https://money.cnn.com/data/markets/',
#  'https://commercial.cnn.com',
#  'https://www.cnn.com/sitemap.html',
#  'https://money.cnn.com/data/markets/',
#  'https://money.cnn.com/data/premarket/',
#  'https://money.cnn.com/data/markets/dow/',
#  'https://money.cnn.com/data/afterhours/',
#  'https://money.cnn.com/data/hotstocks/',
#  'https://money.cnn.com/data/fear-and-greed/',
#  'https://money.cnn.com/data/world_markets/americas/',
#  'https://money.cnn.com/investing/markets-now',
#  'https://money.cnn.com/data/markets/',
#  'https://commercial.cnn.com',
#  'https://www.cnn.com/sitemap.html',
#  'https://commercial.cnn.com',
#  'https://www.cnn.com/sitemap.html',
#  'https://money.cnn.com/data/markets/',
#  'https://money.cnn.com/data/premarket/',
#  'https://money.cnn.com/data/markets/dow/',
#  'https://money.cnn.com/data/afterhours/',
#  'https://money.cnn.com/data/hotstocks/',
#  'https://money.cnn.com/data/fear-and-greed/',
#  'https://money.cnn.com/data/world_markets/americas/',
#  'https://money.cnn.com/investing/markets-now',
#  'http://go.cnn.com/?stream=',
#  'http://searchapp.cnn.com/search/query.jsp',
#  'http://www.cnn.com/profiles/jake-tapper-profile\\',
#  'http://www.cnn.com/profiles/dana-bash-profile\\',
#  'http://www.cnn.com/profiles/ivan-watson\\',
#  'http://www.cnn.com/profiles/wolf-blitzer-profile\\',
#  'http://www.cnn.com/specials/politics/president-donald-trump-45\\',
#  'http://www.cnn.com/2018/11/03/politics/donald-trump-mike-lindell-mypillow-midterms/index.html\\',
#  'http://www.cnn.com/2020/08/15/us/national-zoo-panda-pregnant-trnd/index.html\\',
#  'http://go.cnn.com/?stream=cnni&sr=watchLiveHPbutton&source=edition']
#
# Different domain:
#
# ['https://www.googletagservices.com/tag/js/gpt.js',
#  'https://c.amazon-adsystem.com/aax2/apstag.js',
#  'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js',
#  'https://plus.google.com/+cnn/posts',
#  'https://tvem.cdn.turner.com/v2/getConfig',
#  'https://edition.i.cdn.cnn.com/.a/2.230.1',
#  'https://s3.amazonaws.com/cnn-sponsored-content',
#  'https://bulletin.cnn.io/api/v1/subscribe/',
#  'https://cdn.segment.com/analytics.js/v1/',
#  'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js',
#  'https://www.microsoft.com/edge\\',
#  'https://tvem.cdn.turner.com/v2/getConfig',
#  'https://registry.api.cnn.io/bundles/fave/latest-3.x/css',
#  'https://registry.api.cnn.io/bundles/fave/latest-3.x/js',
#  'https://get.adobe.com/flashplayer/',
#  'https://www.youtube.com/watch?v=Y7xfMHSeiig\\',
#  'https://cnn.com/2013/05/22/showbiz/carey-mulligan-gatsby-era\\',
#  'https://cnn.com/2013/09/10/world/europe/princess-diana-fast-facts/index.html\\',
#  'https://www.medrxiv.org/content/10.1101/2020.08.11.20171843v2\\',
#  'https://cnn.com/2020/03/04/health/smartphone-headache-wellness/index.html\\',
#  'https://www.euromonitor.com/beauty-and-personal-care-in-south-korea/report\\',
#  'https://cnn.com/travel/article/frozen-puppy-intl-scli-scn/index.html\\',
#  'https://mailcar.cnn.io/api/v1/',
#  'https://mailcar.ui.cnn.io/',
#  'https://registry.api.cnn.io/bundles/fave/latest-3.x/css',
#  'https://registry.api.cnn.io/bundles/fave/latest-3.x/js',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.turnerjobs.com/search-jobs?orgIds=1174&amp;ac=19299',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.cnnmoney.ch',
#  'https://www.turnerjobs.com/search-jobs?orgIds=1174&ac=19299',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.turnerjobs.com/search-jobs?orgIds=1174&amp;ac=19299',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.w3.org/2000/svg',
#  'https://www.cnnmoney.ch',
#  'https://www.turnerjobs.com/search-jobs?orgIds=1174&ac=19299',
#  'http://cnn.it/go',
#  'http://localhost.cnn.com:3000/build/api/',
#  'http://cnn.it/go',
#  'http://cnn.com/election\\',
#  'http://cnnnewsource.com',
#  'http://bleacherreport.com',
#  'http://bleacherreport.com/nfl',
#  'http://bleacherreport.com/college-football',
#  'http://bleacherreport.com/nba',
#  'http://bleacherreport.com/mlb',
#  'http://bleacherreport.com/world-football',
#  'http://cnnnewsource.com',
#  'http://cnnnewsource.com',
#  'http://bleacherreport.com',
#  'http://bleacherreport.com/nfl',
#  'http://bleacherreport.com/college-football',
#  'http://bleacherreport.com/nba',
#  'http://bleacherreport.com/mlb',
#  'http://bleacherreport.com/world-football']

# %% [markdown]
# Test with https://www.bbc.com/news/world-europe-53795871

# %%
url = "https://www.bbc.com/news/world-europe-53795871"

same_hname, same_domain, diff_domain = list(), list(), list()

main_hname = hostname(url)
main_domain = domain(main_hname)
path = main_path(url)

hidden_links = sub_links(url)
grouping(hidden_links)

display()
# Out:
# TLD: com
# DOMAIN: bbc.com
# HOSTNAME: www.bbc.com
# PATH: /news/world-europe-53795871
# LINKS:
# Same hostname:
#
# ['https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/news/amp/world-europe-53795871',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/',
#  'https://www.bbc.com/news',
#  'https://www.bbc.com/sport',
#  'https://www.bbc.com/reel',
#  'https://www.bbc.com/worklife',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/culture',
#  'https://www.bbc.com/culture/music',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.com/wwscripts/data',
#  'https://www.bbc.com/wwscripts/flag',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/russian/live/news-53698604',
#  'https://www.bbc.com/news/world-europe-53795871',
#  'https://www.bbc.com/travel/story/20200817-an-icelandic-ritual-for-wellbeing',
#  'https://www.bbc.com/usingthebbc/cookies/how-can-i-change-my-bbc-cookie-settings/']
#
# Same domain:
#
# ['https://account.bbc.com/account?ptrt=https://www.bbc.com/news/world-europe-53795871']
#
# Different domain:
#
# ['https://static.bbc.co.uk/news/1.319.03657/stylesheets/services/news/compact.css',
#  'https://static.bbc.co.uk/news/1.319.03657/stylesheets/services/news/tablet.css',
#  'https://static.bbc.co.uk/news/1.319.03657/stylesheets/services/news/wide.css',
#  'https://www.bbc.co.uk/news/world-europe-53795871',
#  'https://www.facebook.com/bbcnews',
#  'https://ichef.bbci.co.uk/images/ic/1024x576/p08nsn91.jpg',
#  'https://ichef.bbci.co.uk/images/ic/1024x576/p08nsn91.jpg',
#  'https://static.bbc.co.uk/news/1.319.03657/apple-touch-icon-57x57-precomposed.png',
#  'https://static.bbc.co.uk/news/1.319.03657/apple-touch-icon-72x72-precomposed.png',
#  'https://static.bbc.co.uk/news/1.319.03657/apple-touch-icon-114x114-precomposed.png',
#  'https://static.bbc.co.uk/news/1.319.03657/apple-touch-icon.png',
#  'https://static.bbc.co.uk/news/1.319.03657/apple-touch-icon.png',
#  'https://static.bbc.co.uk/news/1.319.03657/web-app-launch-icon.png',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/css/orb-ltr.min.css',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/css/orb-ie-ltr.min.css',
#  'https://www.bbc.co.uk/schedules/p00fzl9m',
#  'https://www.bbc.co.uk/sounds',
#  'https://',
#  'https://www.bbc.co.uk/userprofile',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/js/require.min.js',
#  'https://nav.files.bbci.co.uk/orbit-webmodules/0.0.2-477.3a39ca0/cookie-banner/cookie-library.min.js',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/js/api.min.js',
#  'https://nav.files.bbci.co.uk/orbit-webmodules/0.0.2-477.3a39ca0/istats/istats-1',
#  'https://static.files.bbci.co.uk/account/id-cta/1.48.0/style/id-cta.css',
#  'https://static.files.bbci.co.uk/account/id-cta/1.48.0/style/ie8.css',
#  'https://static.bbc.co.uk/bbcdotcom/4.5.1093/script',
#  'https://static.bbc.co.uk/bbcdotcom/4.5.1093/',
#  'https://static.bbc.co.uk/bbcdotcom/4.5.1093/script/dist/bbcdotcom.dev.js',
#  'https://static.bbc.co.uk/bbcdotcom/4.5.1093/script/dist/bbcdotcom.js',
#  'https://static.bbc.co.uk/bbcdotcom/4.5.1093/',
#  'https://cdn.optimizely.com/public/4621041136/s/bbccom_sandbox.js',
#  'https://cdn.optimizely.com/public/4621041136/s/bbccom_prod.js',
#  'https://nav.files.bbci.co.uk/searchbox/f1713838fc62b38a521a235b3d19f819/',
#  'https://nav.files.bbci.co.uk/searchbox/f1713838fc62b38a521a235b3d19f819/drawer',
#  'https://search.bbc.co.uk/search\\',
#  'https://nav.files.bbci.co.uk/searchbox/f1713838fc62b38a521a235b3d19f819/css/main.css',
#  'https://nav.files.bbci.co.uk/searchbox/f1713838fc62b38a521a235b3d19f819/script/html5shiv.min.js',
#  'https://nav.files.bbci.co.uk/searchbox/f1713838fc62b38a521a235b3d19f819/css/ie8.css',
#  'https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/',
#  'https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/reverb-1.5.0.js',
#  'https://static.bbc.co.uk/news/1.319.03657/stylesheets/services/news/core.css',
#  'https://static.bbc.co.uk/news/1.319.03657/stylesheets/services/news/old-ie.css',
#  'https://static.bbc.co.uk/news/1.319.03657/js/vendor/html5shiv/html5shiv.js',
#  'https://static.bbc.co.uk/news/1.319.03657/icons/generated/icons.fallback.css',
#  'https://a1.api.bbc.co.uk/hit.xiti?&amp;col=1&amp;from=p&amp;ptag=js&amp;s=598253&amp;p=world::europe::news.world.europe.story.53795871.page&amp;x1=[urn:bbc:cps:56dab9ce-f6f3-40d5-abed-1650dfa98f11]&amp;x2=[responsive]&amp;x3=[bbc_website]&amp;x4=[en]&amp;x7=[article]&amp;x8=[reverb-1.5.0-nojs]&amp;x11=[NEWS_GNL]&amp;x12=[NEWS]',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/accessibility/',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://search.bbc.co.uk/search?scope=all',
#  'https://search.bbc.co.uk/search',
#  'https://static.bbc.co.uk/news/1.319.03657/img/brand/generated/news-light.png',
#  'https://static.bbc.co.uk/news/1.319.03657/img/brand/generated/news-light.svg',
#  'https://polling.bbc.co.uk/news/latest_breaking_news?audience=International',
#  'https://twitter.com/intent/tweet?text=BBC+News+-+Belarus%3A+Mass+protest+eclipses+defiant+Belarus+leader%27s+rally&amp;amp;url=',
#  'https://twitter.com/intent/tweet?text=BBC+News+-+Belarus%3A+Mass+protest+eclipses+defiant+Belarus+leader%27s+rally&amp;amp;url=',
#  'https://twitter.com/intent/tweet?text=BBC+News+-+Belarus%3A+Mass+protest+eclipses+defiant+Belarus+leader%27s+rally&amp;amp;url=',
#  'https://www.bbc.co.uk/faqs/questions/bbc_online/sharing',
#  'https://ichef.bbci.co.uk/images/ic/720x405/p08nsn91.jpg',
#  'https://ichef.bbci.co.uk/news/320/cpsprodpb/13F6F/production/_113957718_062928792-1.jpg',
#  'https://www.bbc.co.uk/news/world-europe-53776461',
#  'https://www.bbc.co.uk/news/world-europe-53727243',
#  'https://www.bbc.co.uk/news/help-50068132',
#  'https://www.bbc.co.uk/news/10628323',
#  'https://www.bbc.co.uk/news/20039682',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://advertising.bbcworldwide.com/',
#  'https://www.bbc.co.uk/usingthebbc/terms/',
#  'https://www.bbc.co.uk/aboutthebbc',
#  'https://www.bbc.co.uk/usingthebbc/privacy/',
#  'https://www.bbc.co.uk/usingthebbc/cookies/',
#  'https://www.bbc.co.uk/accessibility/',
#  'https://www.bbc.co.uk/guidance',
#  'https://www.bbc.co.uk/contact',
#  'https://www.bbc.co.uk/bbcnewsletter',
#  'https://www.bbc.co.uk/help/web/links/',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/',
#  'https://nav.files.bbci.co.uk/orbit/b3428ed36e7e195dbf298117ef155a8f/js/orb.min.js',
#  'https://nav.files.bbci.co.uk/orbit-webmodules/0.0.2-477.3a39ca0/cookie-banner/cookie-banners.bundle.js',
#  'https://nav.files.bbci.co.uk//user-activity-helper/1d5fa47d9ba60d5c52b377ec3208b7be/js/detectview.bundle.js',
#  'http://www.bbc.co.uk/help/web/sharing.shtml',
#  'http://www.facebook.com/dialog/feed?app_id=58567469885&amp;redirect_uri=https%3A%2F%2Fwww.bbc.com%2Fnews%2Fworld-europe-53795871&amp;link=https%3A%2F%2Fwww.bbc.com%2Fnews%2Fworld-europe-53795871%3FSThisFB&amp;display=popup',
#  'http://www.facebook.com/dialog/send?app_id=58567469885&amp;redirect_uri=https%3A%2F%2Fwww.bbc.com%2Fnews%2Fworld-europe-53795871&amp;link=https%3A%2F%2Fwww.bbc.com%2Fnews%2Fworld-europe-53795871%3FSThisFB&amp;display=popup']

# %% [markdown]
# Test with  https://www.f-secure.com/en/about-us/careers/job-openings

# %%
url = "https://www.f-secure.com/en/about-us/careers/job-openings"

same_hname, same_domain, diff_domain = list(), list(), list()

main_hname = hostname(url)
main_domain = domain(main_hname)
path = main_path(url)

hidden_links = sub_links(url)
grouping(hidden_links)

display()
# Out:
# TLD: com
# DOMAIN: f-secure.com
# HOSTNAME: www.f-secure.com
# PATH: /en/about-us/careers/job-openings
# LINKS:
# Same hostname:
#
# ['https://www.f-secure.com/en/about-us/careers/job-openings',
#  'https://www.f-secure.com/content/dam/f-secure/en/about/careers/og/og-job-opening.jpg',
#  'https://www.f-secure.com/en/about-us/careers/job-openings',
#  'https://www.f-secure.com/gb-en/about-us/careers/job-openings',
#  'https://www.f-secure.com/us-en/about-us/careers/job-openings',
#  'https://www.f-secure.com/en/about-us/careers/job-openings',
#  'https://www.f-secure.com/en',
#  'https://www.f-secure.com/en/web/investors_global/home',
#  'https://www.f-secure.com/en/home',
#  'https://www.f-secure.com/en/home',
#  'https://www.f-secure.com/en/home/products',
#  'https://www.f-secure.com/en/home/download',
#  'https://www.f-secure.com/en/home/buy-or-renew',
#  'https://www.f-secure.com/en/business',
#  'https://www.f-secure.com/en/business',
#  'https://www.f-secure.com/en/business/solutions',
#  'https://www.f-secure.com/en/business/support-and-downloads',
#  'https://www.f-secure.com/en/business/contact-us',
#  'https://www.f-secure.com/en/partners',
#  'https://www.f-secure.com/en/partners',
#  'https://www.f-secure.com/en/partners/portals-login',
#  'https://www.f-secure.com/en/consulting',
#  'https://www.f-secure.com/en/consulting',
#  'https://www.f-secure.com/en/consulting/who-we-are',
#  'https://www.f-secure.com/en/consulting/our-thinking',
#  'https://www.f-secure.com/en/consulting/events',
#  'https://www.f-secure.com/en/about-us',
#  'https://www.f-secure.com/en/about-us',
#  'https://www.f-secure.com/en/press',
#  'https://www.f-secure.com/en/investors',
#  'https://www.f-secure.com/en/about-us/careers',
#  'https://www.f-secure.com/en/about-us/contact-us/our-offices',
#  'https://www.f-secure.com/en/business/support-and-downloads/submit-a-sample',
#  'https://www.f-secure.com/en/home/support',
#  'https://www.f-secure.com/en/business/support-and-downloads?a=support',
#  'https://www.f-secure.com',
#  'https://www.f-secure.com/en/legal/terms/websites',
#  'https://www.f-secure.com/en/legal/privacy/websites',
#  'https://www.f-secure.com/en/about-us/contact-us']
#
# Same domain:
#
# ['https://press.f-secure.com/',
#  'https://my.f-secure.com/login?locale=en',
#  'https://labs.f-secure.com',
#  'https://labs.f-secure.com',
#  'https://labs.f-secure.com/blog',
#  'https://labs.f-secure.com/tools',
#  'https://labs.f-secure.com/advisories',
#  'https://community.f-secure.com/t5/English/ct-p/english',
#  'https://community.f-secure.com/',
#  'https://blog.f-secure.com',
#  'https://blog.f-secure.com',
#  'https://blog.f-secure.com']
#
# Different domain:
#
# ['https://www.enable-javascript.com/',
#  'https://addsearch.com/js/?key=6156eca05ef73cc2babc21da4a20c344&amp;categories=1xen',
#  'https://cdn.jobylon.com/jobs/companies/505/embed/v3/?target=jobylon-jobs-widget&amp;show_filters=1&amp;page_size=10',
#  'https://www.facebook.com/pages/F-Secure/107471754306',
#  'https://twitter.com/FSecure',
#  'https://www.youtube.com/user/FSecureNews',
#  'https://www.linkedin.com/company/f-secure-corporation',
#  'https://www.google.com/recaptcha/api.js?onload=onloadCallback&amp;render=explicit',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg',
#  'http://www.w3.org/2000/svg']
